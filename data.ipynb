# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %%
import os
path = r"C:\Guvi_Zen\phone_pay\pulse\data\aggregated\transaction\country\india\state"
Agg_state_list=os.listdir(path)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
# %pip install pandas
# %pip install matplotlib seaborn sqlalchemy pymysql
# %pip install streamlit
# Out:
# Requirement already satisfied: pandas in .\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in .\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in .\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in .\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: sqlalchemy in .\.venv\lib\site-packages (2.0.48)
# Requirement already satisfied: pymysql in .\.venv\lib\site-packages (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in .\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in .\.venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in .\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in .\.venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in .\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in .\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: greenlet>=1 in .\.venv\lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in .\.venv\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit in .\.venv\lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\.venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\.venv\lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in .\.venv\lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\.venv\lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in .\.venv\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging>=20 in .\.venv\lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in .\.venv\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\.venv\lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in .\.venv\lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in .\.venv\lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in .\.venv\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\.venv\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in .\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in .\.venv\lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\.venv\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in .\.venv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.1)
# Requirement already satisfied: colorama in .\.venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in .\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in .\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path = r"C:\Guvi_Zen\phone_pe\pulse\data\aggregated\transaction\country\india\state"
Agg_trans_state_list=os.listdir(path)
Agg_trans_state_list
#Agg_state_list--> to get the list of states in India
#-------------------
#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_trans_state_list:
    p_i=os.path.join(path,i)
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=os.path.join(p_i, j)
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=os.path.join(p_j, k)
            with open(p_k,'r') as Data:
                D=json.load(Data)
                for z in D['data']['transactionData']:
                  Name=z['name']
                  count=z['paymentInstruments'][0]['count']
                  amount=z['paymentInstruments'][0]['amount']
                  clm['Transaction_type'].append(Name)
                  clm['Transacion_count'].append(count)
                  clm['Transacion_amount'].append(amount)
                  clm['State'].append(i)
                  clm['Year'].append(j)
                  clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_trans=pd.DataFrame(clm)
Agg_trans
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 5029                west-bengal  2024       4         Merchant payments
# 5030                west-bengal  2024       4     Peer-to-peer payments
# 5031                west-bengal  2024       4  Recharge & bill payments
# 5032                west-bengal  2024       4        Financial Services
# 5033                west-bengal  2024       4                    Others
#
#       Transacion_count  Transacion_amount
# 0                 4200       1.845307e+06
# 1                 1871       1.213866e+07
# 2                  298       4.525072e+05
# 3                   33       1.060142e+04
# 4                  256       1.846899e+05
# ...                ...                ...
# 5029         655100809       3.892862e+11
# 5030         493217788       1.361927e+12
# 5031          76043195       5.753406e+10
# 5032           2352084       8.472965e+08
# 5033            421806       5.053641e+08
#
# [5034 rows x 6 columns]

# %%
from sqlalchemy import create_engine
engine =  create_engine(f"mysql+pymysql://root:Sql25@localhost:3306/phone_pe")
conn = engine.connect()

# %%
Agg_trans.to_sql("agg_trans",con = engine, if_exists = "replace",index = False)
# Out:
# 5034

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
def visualize_table(df, group_col, value_col, title):


    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()

Agg_trans = pd.read_sql("SELECT * FROM agg_trans", con=engine)
visualize_table(Agg_trans, 'State', 'Transacion_amount', 'Aggregated Transaction')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\163744515.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\aggregated\insurance\country\india\state"
Agg_state_list=os.listdir(path)
Agg_state_list

clm={'State':[], 'Year':[],'Quater':[],'Insurance_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=os.path.join(path,i)
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Insurance_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))


Agg_Insurance=pd.DataFrame(clm)
display(Agg_Insurance)
Agg_Insurance.to_csv("Agg_Insurance.csv", index=False)
print("Aggregated Insurance Data Saved as Agg_Insurance.csv")
# Out:
#                          State  Year  Quater Insurance_type  Insurance_count  \
# 0    andaman-&-nicobar-islands  2020       2      Insurance                6
# 1    andaman-&-nicobar-islands  2020       3      Insurance               41
# 2    andaman-&-nicobar-islands  2020       4      Insurance              124
# 3    andaman-&-nicobar-islands  2021       1      Insurance              225
# 4    andaman-&-nicobar-islands  2021       2      Insurance              137
# ..                         ...   ...     ...            ...              ...
# 677                west-bengal  2023       4      Insurance            72712
# 678                west-bengal  2024       1      Insurance            79576
# 679                west-bengal  2024       2      Insurance            67048
# 680                west-bengal  2024       3      Insurance            77158
# 681                west-bengal  2024       4      Insurance            91719
#
#      Insurance_amount
# 0              1360.0
# 1             15380.0
# 2            157975.0
# 3            244266.0
# 4            181504.0
# ..                ...
# 677       100365562.0
# 678       104987909.0
# 679        89476633.0
# 680       107451766.0
# 681       120602777.0
#
# [682 rows x 6 columns]
# Aggregated Insurance Data Saved as Agg_Insurance.csv

# %%
Agg_Insurance.to_sql("agg_insurance",con = engine, if_exists = "replace",index = False)
# Out:
# 682

# %%
agg_insurance = pd.read_sql("SELECT * FROM agg_insurance", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
    
visualize_table(agg_insurance, 'State', 'Insurance_amount', 'Aggregated Insurance')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\2716156.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path = r"C:\Guvi_Zen\phone_pe\pulse\data\aggregated\user\country\india\state"
Agg_state_list=os.listdir(path)
Agg_state_list


clm = {'State': [], 'Year': [], 'Quarter': [],'User_brand': [], 'User_count': [], 'User_percentage': []}

for i in Agg_state_list:
    p_i = os.path.join(path, i)
    if not os.path.isdir(p_i):
        continue
    Agg_yr = os.listdir(p_i)
    for j in Agg_yr:
        p_j = os.path.join(p_i, j)
        if not os.path.isdir(p_j):
            continue
        Agg_yr_list = os.listdir(p_j)
        for k in Agg_yr_list:
            p_k = os.path.join(p_j, k)
            try:
                with open(p_k, 'r') as f:
                    D = json.load(f)
            except:
                continue
            users = D.get('data', {}).get('usersByDevice')
            if users and isinstance(users, list):
                for z in users:
                    clm['User_brand'].append(z.get('brand'))
                    clm['User_count'].append(z.get('count'))
                    clm['User_percentage'].append(z.get('percentage'))
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quarter'].append(int(k.strip('.json')))

Agg_User = pd.DataFrame(clm)
display(Agg_User)
Agg_User.to_csv("Agg_User.csv", index=False)
print("Aggregated User Data Saved as Agg_User.csv")
# Out:
#                           State  Year  Quarter User_brand  User_count  \
# 0     andaman-&-nicobar-islands  2018        1     Xiaomi        1665
# 1     andaman-&-nicobar-islands  2018        1    Samsung        1445
# 2     andaman-&-nicobar-islands  2018        1       Vivo         982
# 3     andaman-&-nicobar-islands  2018        1       Oppo         501
# 4     andaman-&-nicobar-islands  2018        1    OnePlus         332
# ...                         ...   ...      ...        ...         ...
# 6727                west-bengal  2022        1     Lenovo      330017
# 6728                west-bengal  2022        1    Infinix      284678
# 6729                west-bengal  2022        1       Asus      280347
# 6730                west-bengal  2022        1      Apple      277752
# 6731                west-bengal  2022        1     Others     2196334
#
#       User_percentage
# 0            0.247033
# 1            0.214392
# 2            0.145697
# 3            0.074332
# 4            0.049258
# ...               ...
# 6727         0.015056
# 6728         0.012987
# 6729         0.012790
# 6730         0.012671
# 6731         0.100199
#
# [6732 rows x 6 columns]
# Aggregated User Data Saved as Agg_User.csv

# %%
Agg_User.to_sql("agg_user",con = engine, if_exists = "replace",index = False)
# Out:
# 6732

# %%
agg_user = pd.read_sql("SELECT * FROM agg_user", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
    
visualize_table(agg_user, 'State', 'User_count', 'Aggregated User')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\622757484.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\map\transaction\hover\country\india\state"
map_state_list=os.listdir(path)
map_state_list

clm={'State':[], 'Year':[],'Quater':[],'District':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in map_state_list:
    p_i=os.path.join(path,i)
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j = os.path.join(p_i, j)
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['District'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))


map_Trans=pd.DataFrame(clm)
display(map_Trans)
map_Trans.to_csv("map_Trans.csv", index=False)
print("map Transaction Data Saved as map_Trans.csv")
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20599                west-bengal  2024       4
# 20600                west-bengal  2024       4
# 20601                west-bengal  2024       4
# 20602                west-bengal  2024       4
# 20603                west-bengal  2024       4
#
#                                 District  Transacion_count  Transacion_amount
# 0      north and middle andaman district               442       9.316631e+05
# 1                 south andaman district              5688       1.256025e+07
# 2                      nicobars district               528       1.139849e+06
# 3      north and middle andaman district               825       1.317863e+06
# 4                 south andaman district              9395       2.394824e+07
# ...                                  ...               ...                ...
# 20599                alipurduar district          15875637       2.099251e+10
# 20600         paschim bardhaman district          56616799       6.968735e+10
# 20601                     nadia district          65274337       1.079320e+11
# 20602                   birbhum district          36905213       5.778701e+10
# 20603           purba medinipur district          67833775       1.142771e+11
#
# [20604 rows x 6 columns]
# map Transaction Data Saved as map_Trans.csv

# %%
map_Trans.to_sql("map_trans",con = engine, if_exists = "replace",index = False)
# Out:
# 20604

# %%
map_trans = pd.read_sql("SELECT * FROM map_Trans", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
    
visualize_table(map_trans, 'State', 'Transacion_amount', 'Map Transaction')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\2514611141.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\map\insurance\hover\country\india\state"
map_state_list=os.listdir(path)
map_state_list

clm={'State':[], 'Year':[],'Quater':[],'District':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in map_state_list:
    p_i=os.path.join(path,i)
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j = os.path.join(p_i, j)
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['District'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))


map_Insurance=pd.DataFrame(clm)
display(map_Insurance)
map_Insurance.to_csv("map_Insurance.csv", index=False)
print("map_Insurance Data Saved as map_Insurance.csv")
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 13871                west-bengal  2024       4
# 13872                west-bengal  2024       4
# 13873                west-bengal  2024       4
# 13874                west-bengal  2024       4
# 13875                west-bengal  2024       4
#
#                                 District  Insurance_count  Insurance_amount
# 0                 south andaman district                3             795.0
# 1                      nicobars district                3             565.0
# 2      north and middle andaman district                1             281.0
# 3                 south andaman district               35           13651.0
# 4                      nicobars district                5            1448.0
# ...                                  ...              ...               ...
# 13871                alipurduar district             1023         1613143.0
# 13872         paschim bardhaman district             4945         7005851.0
# 13873                     nadia district             3807         5031294.0
# 13874                   birbhum district             1818         2423290.0
# 13875           purba medinipur district             3559         4439061.0
#
# [13876 rows x 6 columns]
# map_Insurance Data Saved as map_Insurance.csv

# %%
map_Insurance.to_sql("map_insurance",con = engine, if_exists = "replace",index = False)
# Out:
# 13876

# %%
map_insurance = pd.read_sql("SELECT * FROM map_insurance", con=engine)
visualize_table(map_insurance, 'State', 'Insurance_amount', 'Map Insurance')

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\2514611141.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\map\user\hover\country\india\state"
map_state_list=os.listdir(path)
map_state_list

clm={'State':[], 'Year':[],'Quater':[],'District':[], 'User_count':[], 'User_percentage':[]}

for i in map_state_list:
    p_i=os.path.join(path,i)
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j = os.path.join(p_i, j)
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)

            if D['data']['hoverData'] is not None:
                for district, data in D['data']['hoverData'].items():
                    Name=district
                    count=data['registeredUsers']
                    percentage=data['appOpens']
                    clm['District'].append(Name)
                    clm['User_count'].append(count)
                    clm['User_percentage'].append(percentage)
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))
map_User=pd.DataFrame(clm)
display(map_User)
map_User.to_csv("map_User.csv", index=False)
print("map_User Data Saved as map_User.csv")
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20603                west-bengal  2024       4
# 20604                west-bengal  2024       4
# 20605                west-bengal  2024       4
# 20606                west-bengal  2024       4
# 20607                west-bengal  2024       4
#
#                                 District  User_count  User_percentage
# 0      north and middle andaman district         632                0
# 1                 south andaman district        5846                0
# 2                      nicobars district         262                0
# 3      north and middle andaman district         911                0
# 4                 south andaman district        8143                0
# ...                                  ...         ...              ...
# 20603                alipurduar district      475688         31842355
# 20604         paschim bardhaman district     1468252         80543469
# 20605                     nadia district     1861738         98740305
# 20606                   birbhum district     1114220         73465525
# 20607           purba medinipur district     1717074        108350777
#
# [20608 rows x 6 columns]
# map_User Data Saved as map_User.csv

# %%
map_User.to_sql("map_user",con = engine, if_exists = "replace",index = False)
# Out:
# 20608

# %%
map_user = pd.read_sql("SELECT * FROM map_User", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
visualize_table(map_user, 'State', 'User_count', 'Map User')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\2046018913.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\top\transaction\country\india\state"
top_state_list=os.listdir(path)

clm_top_trans={'State':[], 'Year':[],'Quater':[],'Entity_Name':[], 'Entity_Type':[], 'Transacion_count':[], 'Transacion_amount':[]}

for i in top_state_list:
    p_i=os.path.join(path,i)
    top_yr=os.listdir(p_i)
    for j in top_yr:
        p_j = os.path.join(p_i, j)
        top_yr_list=os.listdir(p_j)
        for k in top_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)

            if 'data' in D and D['data'] is not None:
                if 'states' in D['data'] and D['data']['states'] is not None:
                    for z in D['data']['states']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm_top_trans['Entity_Name'].append(Name)
                        clm_top_trans['Entity_Type'].append('State')
                        clm_top_trans['Transacion_count'].append(count)
                        clm_top_trans['Transacion_amount'].append(amount)
                        clm_top_trans['State'].append(i)
                        clm_top_trans['Year'].append(j)
                        clm_top_trans['Quater'].append(int(k.strip('.json')))

                if 'districts' in D['data'] and D['data']['districts'] is not None:
                    for z in D['data']['districts']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm_top_trans['Entity_Name'].append(Name)
                        clm_top_trans['Entity_Type'].append('District')
                        clm_top_trans['Transacion_count'].append(count)
                        clm_top_trans['Transacion_amount'].append(amount)
                        clm_top_trans['State'].append(i)
                        clm_top_trans['Year'].append(j)
                        clm_top_trans['Quater'].append(int(k.strip('.json')))

                if 'pincodes' in D['data'] and D['data']['pincodes'] is not None:
                    for z in D['data']['pincodes']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm_top_trans['Entity_Name'].append(Name)
                        clm_top_trans['Entity_Type'].append('Pincode')
                        clm_top_trans['Transacion_count'].append(count)
                        clm_top_trans['Transacion_amount'].append(amount)
                        clm_top_trans['State'].append(i)
                        clm_top_trans['Year'].append(j)
                        clm_top_trans['Quater'].append(int(k.strip('.json')))

Top_Trans = pd.DataFrame(clm_top_trans)
display(Top_Trans)
Top_Trans.to_csv("Top_Trans.csv", index=False)
print("Top_Trans Data Saved as Top_Trans.csv")
# Out:
#                            State  Year  Quater               Entity_Name  \
# 0      andaman-&-nicobar-islands  2018       1             south andaman
# 1      andaman-&-nicobar-islands  2018       1                  nicobars
# 2      andaman-&-nicobar-islands  2018       1  north and middle andaman
# 3      andaman-&-nicobar-islands  2018       1                    744101
# 4      andaman-&-nicobar-islands  2018       1                    744103
# ...                          ...   ...     ...                       ...
# 18290                west-bengal  2024       4                    711101
# 18291                west-bengal  2024       4                    700059
# 18292                west-bengal  2024       4                    700039
# 18293                west-bengal  2024       4                    734001
# 18294                west-bengal  2024       4                    733134
#
#       Entity_Type  Transacion_count  Transacion_amount
# 0        District              5688       1.256025e+07
# 1        District               528       1.139849e+06
# 2        District               442       9.316631e+05
# 3         Pincode              1622       2.769298e+06
# 4         Pincode              1223       2.238042e+06
# ...           ...               ...                ...
# 18290     Pincode           6753348       1.049483e+10
# 18291     Pincode           6662715       8.009476e+09
# 18292     Pincode           6575693       9.018748e+09
# 18293     Pincode           6432082       8.996529e+09
# 18294     Pincode           6313560       1.050259e+10
#
# [18295 rows x 7 columns]
# Top_Trans Data Saved as Top_Trans.csv

# %%
Top_Trans.to_sql("top_trans",con = engine, if_exists = "replace",index = False)
# Out:
# 18295

# %%
top_trans = pd.read_sql("SELECT * FROM top_trans", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
visualize_table(top_trans, 'State', 'Transacion_count', 'Top Transactions')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\3479801025.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\top\insurance\country\india\state"
top_state_list=os.listdir(path)
top_state_list

clm={'State':[], 'Year':[],'Quater':[],'Entity_Name':[], 'Entity_Type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in top_state_list:
    p_i=os.path.join(path,i)
    top_yr=os.listdir(p_i)
    for j in top_yr:
        p_j = os.path.join(p_i, j)
        top_yr_list=os.listdir(p_j)
        for k in top_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)
            if 'data' in D and D['data'] is not None:
                if 'states' in D['data'] and D['data']['states'] is not None:
                    for z in D['data']['states']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm['Entity_Name'].append(Name)
                        clm['Entity_Type'].append('State')
                        clm['Insurance_count'].append(count)
                        clm['Insurance_amount'].append(amount)
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.strip('.json')))

                if 'districts' in D['data'] and D['data']['districts'] is not None:
                    for z in D['data']['districts']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm['Entity_Name'].append(Name)
                        clm['Entity_Type'].append('District')
                        clm['Insurance_count'].append(count)
                        clm['Insurance_amount'].append(amount)
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.strip('.json')))

                if 'pincodes' in D['data'] and D['data']['pincodes'] is not None:
                    for z in D['data']['pincodes']:
                        Name=z['entityName']
                        count=z['metric']['count']
                        amount=z['metric']['amount']
                        clm['Entity_Name'].append(Name)
                        clm['Entity_Type'].append('Pincode')
                        clm['Insurance_count'].append(count)
                        clm['Insurance_amount'].append(amount)
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quater'].append(int(k.strip('.json')))

top_insurance = pd.DataFrame(clm)
display(top_insurance)
top_insurance.to_csv("top_insurance.csv", index=False)
print("top_insurance Data Saved as top_insurance.csv")
# Out:
#                            State  Year  Quater    Entity_Name Entity_Type  \
# 0      andaman-&-nicobar-islands  2020       2       nicobars    District
# 1      andaman-&-nicobar-islands  2020       2  south andaman    District
# 2      andaman-&-nicobar-islands  2020       2         744301     Pincode
# 3      andaman-&-nicobar-islands  2020       2         744104     Pincode
# 4      andaman-&-nicobar-islands  2020       2         744101     Pincode
# ...                          ...   ...     ...            ...         ...
# 12271                west-bengal  2024       4         711101     Pincode
# 12272                west-bengal  2024       4         700091     Pincode
# 12273                west-bengal  2024       4         700150     Pincode
# 12274                west-bengal  2024       4         700039     Pincode
# 12275                west-bengal  2024       4         700156     Pincode
#
#        Insurance_count  Insurance_amount
# 0                    3             565.0
# 1                    3             795.0
# 2                    3             565.0
# 3                    2             513.0
# 4                    1             282.0
# ...                ...               ...
# 12271              713          750354.0
# 12272              642          969634.0
# 12273              627          761501.0
# 12274              619          787836.0
# 12275              574          888613.0
#
# [12276 rows x 7 columns]
# top_insurance Data Saved as top_insurance.csv

# %%
top_insurance.to_sql("top_insurance",con = engine, if_exists = "replace",index = False)
# Out:
# 12276

# %%
top_insurance = pd.read_sql("SELECT * FROM top_insurance", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
visualize_table(top_insurance, 'State', 'Insurance_amount', 'Top Insurance')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\258744962.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')

# %%
path=r"C:\Guvi_Zen\phone_pe\pulse\data\top\user\country\india\state"
top_state_list=os.listdir(path)

clm_top_user={'State':[], 'Year':[],'Quater':[],'Entity_Name':[], 'Entity_Type':[], 'User_count':[]}

for i in top_state_list:
    p_i=os.path.join(path,i)
    top_yr=os.listdir(p_i)
    for j in top_yr:
        p_j = os.path.join(p_i, j)
        top_yr_list=os.listdir(p_j)
        for k in top_yr_list:
            p_k = os.path.join(p_j, k)
            Data=open(p_k,'r')
            D=json.load(Data)
            try:
              for z in D['data']['districts']:

                        Name=z['name']
                        count=z['registeredUsers']
                        clm_top_user['Entity_Name'].append(Name)
                        clm_top_user['Entity_Type'].append('State')
                        clm_top_user['User_count'].append(count)
                        clm_top_user['State'].append(i)
                        clm_top_user['Year'].append(j)
                        clm_top_user['Quater'].append(int(k.strip('.json')))

              for z in D['data']['pincode']:

                        Name=z['name']
                        count=z['registeredUsers']
                        clm_top_user['Entity_Name'].append(Name)
                        clm_top_user['Entity_Type'].append('State')
                        clm_top_user['User_count'].append(count)
                        clm_top_user['State'].append(i)
                        clm_top_user['Year'].append(j)
                        clm_top_user['Quater'].append(int(k.strip('.json')))
            except:
                pass

top_user=pd.DataFrame(clm_top_user)
display(top_user)
top_user.to_csv("top_user.csv", index=False)
print("top_user Data Saved as top_user.csv")
# Out:
#                           State  Year  Quater               Entity_Name  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018       1                  nicobars
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2  north and middle andaman
# ...                         ...   ...     ...                       ...
# 8291                west-bengal  2024       4                   hooghly
# 8292                west-bengal  2024       4                     nadia
# 8293                west-bengal  2024       4           purba medinipur
# 8294                west-bengal  2024       4         paschim medinipur
# 8295                west-bengal  2024       4         paschim bardhaman
#
#      Entity_Type  User_count
# 0          State        5846
# 1          State         632
# 2          State         262
# 3          State        8143
# 4          State         911
# ...          ...         ...
# 8291       State     1957356
# 8292       State     1861738
# 8293       State     1717074
# 8294       State     1522845
# 8295       State     1468252
#
# [8296 rows x 6 columns]
# top_user Data Saved as top_user.csv

# %%
top_user.to_sql("top_user",con = engine, if_exists = "replace",index = False)
# Out:
# 8296

# %%
top_user = pd.read_sql("SELECT * FROM top_user", con=engine)

def visualize_table(df, group_col, value_col, title):
    
    top10 = df.groupby(group_col)[value_col].sum().reset_index().sort_values(by=value_col, ascending=False).head(10)
    plt.figure(figsize=(10,5))
    plt.bar(np.arange(len(top10)), top10[value_col], color='coral')
    plt.xticks(np.arange(len(top10)), top10[group_col], rotation=45)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Top 10 {group_col} by {value_col} ({title})')
    plt.tight_layout()
    plt.show()
    
    full = df.groupby(group_col)[value_col].sum().reset_index()
    plt.figure(figsize=(14,7))
    sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
    plt.xticks(rotation=90)
    plt.xlabel(group_col)
    plt.ylabel(value_col)
    plt.title(f'Total {value_col} by {group_col} ({title})')
    plt.tight_layout()
    plt.show()
visualize_table(top_user, 'State', 'User_count', 'Top Users')
# Out:
# C:\Users\kanag\AppData\Local\Temp\ipykernel_3488\3661234628.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_col, y=value_col, data=full, palette='viridis')
